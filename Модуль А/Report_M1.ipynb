# %% [markdown]
# # Предобработка количественных данных

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Загрузка данных
# #### - 1.1 Данные были взяты из сервиса РосНавык.
# #### - 1.2 Также были взяты данные из открытых источников, с реализацией парсера в файле -> parser.py.
# #### - 1.3 Собранные данные содержат информацию в промежутке последних 3-х месяцев.
# #### - 1.4 Среди полей данных присутсвуют требуемые в задании поля

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Предобработка данных
# #### - 2.1 Я определил и обосновал основные атрибуты в файле -> Report.html.
# #### - 2.2 Привел все данные в базе к нижнему регистру.
# #### - 2.3 Задал верную структуру базы данных: добавил поле ИД и первичный ключ для базы данных.
# #### - 2.4 Произвел преобразование типов данных: задал всем полям верные типы данных.
# #### - 2.5 Опредлил кретические прпоущенные значения в файле -> Report.html.
# #### - 2.6 Оценил погрешность при допустимом количестве пропущенных значений в 50% в файле -> Report.html.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Описание структуры набора данных
# #### - 3.1 Привел для каждого атрибута текстовое описание в файле -> Report.html.
# #### - 3.2 Для каждого атрибута привел количество пропущенных значений в файле -> Report.html.
# #### - 3.3 Для каждого атрибута привел анализ плотности распределения значений в файле -> Report.html.
# #### - 3.4 Подгтовил файл с преобработанной базой данных в папке data -> cleardata -> csvcleardata.csv.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Запросы на выборку данных из базы данных
# #### - 4.1 Импорт данных был выполнен программно, я использовал DBeaver.
# #### - 4.2 При сборе данных я использовал запросы данных, реализовав парсер в файле -> parser.py.
# #### - 4.3 При обработке данных я использовал SQL запросы к базе, которые отобразил в файле -> ModuleA.sql.
# #### - 4.4 Все SQL запросы к базе покрыты комметариями и соотвествуют стандартным требованиям.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Подготовка отчетов
# #### - 5.1 Сотавил отчет о проделанной работе в файле -> Report_М1.ipynb.
# #### - 5.2 В отчете отраженны все этапы проделанной работы.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________
