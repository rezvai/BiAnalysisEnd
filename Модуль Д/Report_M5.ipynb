# %% [markdown]
# # Презентация решения

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Разработка документации системы
# #### - 1.1 Я создал файл с документацией, охватывающий всю систему в файле ->  Readme.md.
# #### - 1.2 Документация создана по отраслевому стандарту.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Разработка презентации системы
# #### - 2.1 Я создал презентацию, охватывающую всю систему  в файле -> Project.pptx.
# #### - 2.2 Я подготовил доклад о презентации.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Техническая документация
# #### - 3.1 Я закоментировал весь имеющейся код комментариями, которые соответсвуют отраслевому стандарту.
# #### - 3.2 Я постарался закоментировать весь код полезными для понимания комментариями.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
