# %% [markdown]
# # Сетевой анализ данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Граф связей
# #### - 1.1 Я построил граф связей навыков для выбранной группы вакансий в файле - RabovModuleГ.pbix.
# #### - 1.2 Граф связей дает возможность понять, как часто один навык встречается вместе с другими навыками.
# #### - 1.3 Описаны основные метрики полученного графа.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Подготовка рекомендаций
# #### - 2.1 Я подготовил отчет.
# #### - 2.2 Отчет охватывает все результаты проделанной работы.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 3. Описание рекомендаций
# #### - 3.1 Я дал рекомендации образовательным организациям в файле - Recomendations.docx.
# #### - 3.2 Создал интерактивный граф связей в файле - RabovModuleГ.pbix.
# #### - 3.3 В файле присутствует возможность интерактивно взаимодействовать с графом.
# #### - 3.4 Я указал основные метрики и описания к ним.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
