# %% [markdown]
# # Сетевой анализ данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение графа связей
# #### - 1.1 Я построил граф связей навыков для выбранной группы вакансий в файле -> RabovModuleГ.pbix.
# #### - 1.2 Граф связей дает возможность понять, как часто один навык встречается вместе с другими навыками.
# #### - 1.3 Я прлизвел расчет основных метрик полученного графа  в файле -> Report.html.
# #### - 1.4 Создал интерактивный граф связей в файле - RabovModuleГ.pbix.
# #### - 1.5 Присутствует возможность интерактивно взаимодействовать с графом  в файле -> RabovModuleГ.pbix.
# #### - 1.6 Я указал основные метрики и описания к ним  в файле ->  Report.html.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Подготовка рекомендаций
# #### - 2.1 Я подготовил отчет о проделаннйо работе  в файле -> Report_M4.ipynb.
# #### - 2.2 Отчет охватывает все результаты проделанной работы.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 3. Описание рекомендаций
# #### - 3.1 Я дал рекомендации образовательным организациям на основе проведенного анализа в файле -> Recomendations.docx.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
