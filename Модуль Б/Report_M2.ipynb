# %% [markdown]
# # Анализ количественных данных

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение интерактивного дашборда
# #### - 1.1 Я построил график динамики количества вакансий по месяцам в файле -> RabovModuleБ.pbix.
# #### - 1.2 Все элементы из задания присутсвуют на интерактивном дашборде.
# #### - 1.3 Визуализация наглядно отражает рост или снижение показателей, при выборе любого элемента другие элементо моментально изменяются.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Иследовательский анализ данных
# #### - 2.1 Я выявил зависимости между 4-мя переменными, двое из которых выявляют устойчивые линейные зависимости, а другие нет.
# #### - 2.2 Я описал эти закономерности в файле -> Report.html.
# #### - 2.3 Я программно выполнил корелляционный анализ между доходом и уровнем образования в файле -> cor.ipynb.
# #### - 2.4 Я распределил количественны перменные на категории для упрощения анализа в дашборде -> RabovModuleБ.pbix.
# #### - 2.5 Я сопоставил кластеры по вакансиям в дашборде -> RabovModuleБ.pbix.
# #### - 2.6 Я интегрировал базу данных к интерактивному дашборду для регулярного обновления данных в файле -> RabovModuleБ.pbix.
# #### - 2.7 Я опредлил и отфильтровал коррелирующие переменные в дашборде -> RabovModuleБ.pbix.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Подготовка аналитической справки
# #### - 3.1 Я подготовил аналитическую справку в файле -> Analysisnote.docx.
# #### - 3.2 Аналитическая справка охватывает все результаты проделанной работы.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Проектирование информационно аналитических систем
# #### - 4.1 Я реализовал методы защиты данных дашборда в файле -> RabovModuleБ.pbix -> вкладка моделирование -> посмотреть как и выбираем пользователя.
# #### - 4.2 Я реализовал интерактивность дашборда в файле -> RabovModuleБ.pbix.
# #### - 4.3 Интерфейс дашборда выглядит интуитивно понятно.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________
