# %% [markdown]
# # 1. Реализация корреляционного анализа

# %%
# Импортиурем библиотеку для работы с данными
import pandas as pd
# Импортиурем модуль из бибилиотеки для работы со статистическими методами
from scipy.stats import spearmanr

# %%
# Загружаем данные из выгруженного csv в дата фрейм
df = pd.read_csv('csvcleardata.csv', encoding='windows-1251')

# Выводим пример данных
df
# Out:
#                                name  \
# 0   старший аналитик товародвижения
# 1                      bi developer
# 2    аналитик данных / аналитик dwh
# 3                   аналитик данных
# 4                      аналитик dwh
# ..                              ...
# 89                     аналитик dwh
# 90                         аналитик
# 91  it бизнес-аналитик (it проекты)
# 92                  senior аналитик
# 93                     web-аналитик
#
#                                           description  salary  \
# 0   торгово -производственной компании на постоянн...  200000
# 1   best online insurance company in the middle ea...    3000
# 2   финуслуги — это маркетплейс, созданный московс...  300000
# 3   привет! это one company. мы - экосистема девел...   60000
# 4   привет! мы — ооо «датаномика», решаем проблемы...  330000
# ..                                                ...     ...
# 89  привет! мы — ооо «датаномика», решаем проблемы...  330000
# ...

# %%
# Выводим корреляционный анализ переменных: заработная плата и опыт работы
print(f"Корреляционный анализ переменных: заработная плата и опыт работы - {spearmanr(df['salary'], df['work_experience'])}", end='\n\n')
# Выводим корреляционный анализ переменных: заработная плата и регион
print(f"Корреляционный анализ переменных: заработная плата и регион - {spearmanr(df['salary'], df['region_name'])}")
# Out:
# Корреляционный анализ переменных: заработная плата и опыт работы - SignificanceResult(statistic=0.3506124762514379, pvalue=0.0005312301673702078)
#
# Корреляционный анализ переменных: заработная плата и регион - SignificanceResult(statistic=-0.008267579896795392, pvalue=0.936964217955913)

# %% [markdown]
# ### Объяснение полученного вывода
# statistic - указывает на линейную зависимость между переменными в диапозоне от -1 до 1, чем ближе к одному, тем больше зависимость между переменными
