# %% [markdown]
# # Анализ количественных данных

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение интерактивного дашборда
# #### - 1.1 Я построил график динамики количества вакансий по месяцм.
# #### - 1.2 Все элементы из задания присутсвуют на интерактивном дашборде.
# #### - 1.3 Визуализация наглядно отражает рост или снижение показателей.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Поиск зависимотей
# #### - 2.1 Я выявил зависимости между 4-мя переменными, которые проявлются устойчевые зависимости.
# #### - 2.2 Я описал эти закономерности в файле Report.html.
# #### - 2.3 Я пргграммно выполнил корелляционный анализ между доходом и уровнем образования в файле cor.ipynb.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Фильтрация данных
# #### - 3.1 Я распределил количественны перменные на категории для упрощения анализа.
# #### - 3.2 Я сопоставил кластеры по вакансиям.
# #### - 3.3 Я интегрировал базу данных к интерактивному дашборду для регулярного обновления данных.
# #### - 3.4 Я опредлил и отфильтровал коррелирующие переменные.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подготовка отчета о проделанной работе
# #### - 4.1 Я подготовил отчет о проделанной работе.
# #### - 4.2 Отчет охватывает все результаты проделанной работы.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Проектирование информационно аналитических систем
# #### - 5.1 Я реализовал методы защиты данных дашборда.
# #### - 5.2 Интерфейс дашборда выглядит интуитивно понятно.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________
