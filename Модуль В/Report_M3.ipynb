# %% [markdown]
# # Обработка и анализ текстовых данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Предобработка данных
# #### - 1.1 Я провел парсинг с указанных веб сайтов.
# #### - 1.2 Выполнил предобработку данных.
# #### - 1.3 Выполнил задание в полном объеме.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Семантический анализ текста
# #### - 2.1 Я произвел анализ связей между словами, понимания синтаксической и семантической структуры предложений.
# #### - 2.2 Определил функциональные роли слов.
# #### - 2.3 ВЫявил эмоциональную окраску фраз.
# #### - 2.4 Выполнил анализ региональной специфики востребованных вакансий.
# #### - 2.5 Произвел кластеризацию выделенных навыков.
# #### - 2.6 Произвел классификацию выделенных навыков.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Подготовка отчетов
# #### - 3.1 Я подготовил отчет о проделанной работе.
# #### - 3.2 Отчет охватывает результаты всей проделанной работы.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Визуальный анализ статистики текстовых признаков
# #### - 4.1 Я построил таблицу с классами навыков, содержанием, частойтой встречаемости.
# #### - 4.2 Провел визуальный анализ статистики текстовых признаков.
# #### - 4.3 Определил наиболее востребованные навыки.
# #### - 4.4 Определил наименее востребованные навыки.
# #### - 4.5 Определил наиболее высокооплачиваемые навыки.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Проектирование информационно аналитических систем
# #### - 5.1 Я реализовал методы защиты данных.
# #### - 5.2 Выполнил мониторинг отслеживания изменений в данных.
# #### - 5.3 Описал функциональные требований к дашборду в файле - Report.html.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
