# %% [markdown]
# # Обработка и анализ текстовых данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Получение и предобработка данных
# #### - 1.1 Я получил данные из БД в файле -> model.ipynb -> 1 пункт.
# #### - 1.2 Выполнил предобработку данных для дальнейшей работы с NLP алгоритмамив файле -> model.ipynb -> 2 пункт.
# #### - 1.3 Выявил корректные ключевые навыки и описал их в файле -> Report.html.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Анализ текста
# #### - 2.1 Я произвел анализ связей между словами, понимания синтаксической и семантической структуры предложений в файле -> model.ipynb -> 3 пункт(пояснение в большом комментарии).
# #### - 2.2 Определил функциональные роли слов в файле -> model.ipynb -> 3 пункт(пояснение в большом комментарии).
# #### - 2.3 Выполнил анализ региональной специфики востребованных вакансий в файле -> model.ipynb -> 4 пункт -> 4.3 подпункт.
# #### - 2.4 Произвел кластеризацию выделенных навыков в файле -> model.ipynb -> 3 пункт -> 3.3 подпункт.
# #### - 2.5 Произвел классификацию выделенных навыков в файле -> model.ipynb -> 3 пункт -> 3.1 и 3.2 подпункты.
# #### - 2.6 Я построил таблицу с классами навыков, содержанием, частойтой встречаемости в файле -> mainskills.xlsx.
# #### - 2.7 Выполнил заполнение таблицы с помощью python  в файле -> model.ipynb -> 5 пункт.
# #### - 2.8 Определил наиболее востребованные навыки в файле -> model.ipynb -> 4 пункт -> 4.1 подпункт.
# #### - 2.9 Определил наименее востребованные навыки  в файле -> model.ipynb -> 4 пункт -> 4.1 подпункт.
# #### - 2.10 Определил наиболее высокооплачиваемые навыки в файле -> model.ipynb -> 4 пункт -> 4.2 подпункт.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Проектирование информационно аналитических систем
# #### - 3.1 Я реализовал методы защиты данных для дашборда в файле -> RabovModuleВ.pbix -> вкладка моделирование -> посмотреть как и выбираем пользователя.
# #### - 3.2 Я реализовал интерактивность дашборда  в файле -> RabovModuleB.pbix.
# #### - 3.3 Описал функциональные требований к дашборду в файле -> Report.html.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подготовка отчетов
# #### - 4.1 Я подготовил аналитическую записку о проделанной работе  в файле ->  Analysisnote.docx.
# #### - 4.2 Аналитическая записка охватывает результаты всей проделанной работы.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
